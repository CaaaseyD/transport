# %%
import datetime

#get current time
current_datetime = datetime.datetime.now().date()
print(current_datetime)
# Out:
# 2024-03-13

# %%
# Public Transport - Realtime - Alerts - v2
import os
import requests
import json

# API endpoint for Sydney Trains data
api_url = "https://api.transport.nsw.gov.au/v2/gtfs/alerts/sydneytrains"

# Replace 'YOUR_API_KEY' with your actual API key
api_key = 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJqdGkiOiJnTmJnQWhONkpONGl5ZFlCZmtlV1R4b3prVEdYRTl0WW00Z3NWYUg2WkJVIiwiaWF0IjoxNzA5NjgxMzU0fQ.awaB6sZEtAgdg8N2S3ioB1Y3UZeZCaGFbKvQtjk0sqk'

# Set up headers with the API key
headers = {
    'Authorization': f'apikey {api_key}'
}

# Set up parameters, including 'format' as 'json'
params = {
    'format': 'json'
}

# Send a GET request to the API with parameters
response = requests.get(api_url, headers=headers, params=params)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Check if the response contains data
    if response.text:
        # Parse the JSON response
        data = response.json()

        # Specify the filename
        filename = 'sydney_trains_data.json'

        # Check if the file already exists
        if os.path.exists(filename):
            # Replace content if the file exists
            with open(filename, 'w') as json_file:
                json.dump(data, json_file, indent=2)
            print(f"Data has been successfully replaced in {filename}")
        else:
            # Create a new file if it doesn't exist
            with open(filename, 'w') as json_file:
                json.dump(data, json_file, indent=2)
            print(f"Data has been successfully saved to {filename}")
    else:
        print("Error: Empty response received from the API")
else:
    # Print an error message if the request was unsuccessful
    print(f"Error: {response.status_code}")
    print(response.text)
# Out:
# Data has been successfully saved to sydney_trains_data.json

# %%
import pandas as pd

# Load CSV data into a DataFrame
file_path = r'C:\Users\CaseyD\Dropbox\Baimax\PersonalDevelopment\PowerBI\transport\routes_1.csv'
df_csv = pd.read_csv(file_path)

# Display basic information about the DataFrame
print("Basic Information:")
print(df_csv.info())

# Summary statistics
print("\nSummary Statistics:")
print(df_csv.describe())

# Display the first few rows
print("\nFirst Few Rows:")
print(df_csv.head())

# Missing values
print("\nMissing Values:")
print(df_csv.isnull().sum())
# Out:
# Basic Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10883 entries, 0 to 10882
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   operator_name            10883 non-null  object
#  1   operator_id              10883 non-null  object
#  2   contract_id              10515 non-null  object
#  3   my_timetable_route_name  10883 non-null  object
#  4   route_variant_type       10416 non-null  object
#  5   transport_name_id        10883 non-null  int64
#  6   transport_name           10883 non-null  object
#  7   mot_for_interchange_id   10883 non-null  int64
#  8   mot_for_interchange      10883 non-null  object
#  9   efa_route_name           10883 non-null  object
#  10  route_search_name        10883 non-null  object
#  11  service_direction_name   10883 non-null  object
#  12  1st_twitter_handle       7279 non-null   object
# ...

# %%
import os
import requests
import json

# API endpoint for Sydney Trains data
api_url = "api.transport.nsw.gov.au"

# Replace 'YOUR_API_KEY' with your actual API key
api_key = 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJqdGkiOiJnTmJnQWhONkpONGl5ZFlCZmtlV1R4b3prVEdYRTl0WW00Z3NWYUg2WkJVIiwiaWF0IjoxNzA5NjgxMzU0fQ.awaB6sZEtAgdg8N2S3ioB1Y3UZeZCaGFbKvQtjk0sqk'

# Set up headers with the API key
headers = {
    'Authorization': f'apikey {api_key}'
}

# Send a GET request to the API
response = requests.get(api_url, headers=headers)

if response.status_code == 200:
    # Extract the JSON content from the response
    try:
        json_content = response.json()
        # Parse and use the JSON data as needed
        print(json_content)
    except json.JSONDecodeError as e:
        print(f"JSON Decode Error: {e}")
        print(response.text)
    # Handle the binary data separately, if needed
    binary_data = response.content
    # Further processing of binary data can be done here
else:
    print(f"Error: {response.status_code}")
    print(response.text)

# %%
# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Check if the response contains data
    if response.text:
        # Parse the JSON response
        data = response.json()

        # Specify the filename
        filename = 'sydney_trains_data.json'

        # Check if the file already exists
        if os.path.exists(filename):
            # Replace content if the file exists
            with open(filename, 'w') as json_file:
                json.dump(data, json_file, indent=2)
            print(f"Data has been successfully replaced in {filename}")
        else:
            # Create a new file if it doesn't exist
            with open(filename, 'w') as json_file:
                json.dump(data, json_file, indent=2)
            print(f"Data has been successfully saved to {filename}")
    else:
        print("Error: Empty response received from the API")
else:
    # Print an error message if the request was unsuccessful
    print(f"Error: {response.status_code}")
    print(response.text)
